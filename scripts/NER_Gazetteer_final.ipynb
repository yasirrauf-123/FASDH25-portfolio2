# %% [markdown]
# # Geocoding
# This Colab notebook is part of our Digital Humanities course Mini Project No. 2, where we explore how to visualize the places mentioned in news articles over time. Using computational tools, we extract toponyms (place names) from each article, map them, and observe how the geographic focus of the news shifts over time.
#
# In the notebook titled Gaza_NER2_yasir_afreen_bushra, which is a part of our Mini Project No. 2 portfolio, we applied Named Entity Recognition (NER), a Natural Language Processing (NLP) technique, to identify place names in a dataset of 4341 Al Jazeera English articles about the Gaza war, compiled by Inacio Vieira. Although the dataset includes articles from various dates, we applied a filter to include only those published in January 2024, as instructed. Our focus was to extract place names specifically from that month.
#
#  We stored the places we found using NER in a TSV file named ner_counts.tsv, which is also part of our Mini Project No. 2 portfolio. Now, in this Colab notebook, we will apply geocoding to find coordinates for those places and save them in a TSV file named NER_Gazetteer.tsv, which we will later use for mapping purposes.

# %%
# clone our FASDH25-portfolio2 folder here so we will be able to access ner_counts.tsv which contains lists of places for which we are trying to find coordinates using geocoding
# !git clone https://github.com/yasirrauf-123/FASDH25-portfolio2.git
# Out:
# fatal: destination path 'FASDH25-portfolio2' already exists and is not an empty directory.

# %%
# Did minor adjustments by ourselves like changed the username rest of the code is as given by the instructor in the Gaza-NER2 notebook
import requests
import time

geonames_username = "yasir.rauf2"

def get_coordinates(place, username=geonames_username, fuzzy=0, timeout=1):
  """This function gets a single set of coordinates from the geonames API.

  Args:
    place (str): the place name
    username (str): your geonames user name
    fuzzy (int): 0 = exact matching, 1 = fuzzy matching (allow similar but not exact matches)
    timeout (int): number of seconds to wait before a call to the geonames API
      (to avoid being blocked for overloading the server)

  Returns:
    dictionary: keys: latitude, longitude
  """
  # wait a short while, so that we don't overload the server:
  time.sleep(timeout)
  # make the API call:
  url = "http://api.geonames.org/searchJSON?"
  params = {"q": place, "username": username, "fuzzy": fuzzy, "maxRows": 1, "isNameRequired": True}
  response = requests.get(url, params=params)
  # convert the response into a dictionary:
  results = response.json()
  print(results)
  # get the first result:
  try:
    result = results["geonames"][0]
    return {"latitude": result["lat"], "longitude": result["lng"]}
  except (IndexError, KeyError):
    print("No results found for your API call", response.request.url)

# %%
# Code was modified by ourselves but asked ChatGPT to help us understand the code (See ChatGPT Solutions No.)
# Define the path to the input file containing place names (from NER output)
input_filename = "/content/FASDH25-portfolio2/scripts/ner_counts.tsv"

# Define the path to the output file that will store the geocoded gazetteer
output_filename = "/content/FASDH25-portfolio2/scripts/ner_gazetteer.tsv"

# Open the input file in read mode using UTF-8 encoding
with open(input_filename, "r", encoding="utf-8") as file:
    # Read all lines from the file into a list
    lines = file.readlines()

# Extract place names by skipping the header and taking the first column from each line because it contains the names we will geocode
place_names = [line.strip().split("\t")[0] for line in lines[1:]]

# Open the output file in write mode to save the final results
with open(output_filename, "w", encoding="utf-8") as out_file:
    # Write the header row with column names as required: placename, latitude, longitude
    out_file.write("placename\tlatitude\tlongitude\n")

    # Loop through each place name to find its coordinates
    for name in place_names:
        # Call the get_coordinates function
        coordinates = get_coordinates(name)

        # If coordinates are successfully found
        if coordinates:
            lat = coordinates['latitude']    # Extract latitude
            lon = coordinates['longitude']   # Extract longitude
            # Write the place name with its coordinates to the output file
            out_file.write(f"{name}\t{lat}\t{lon}\n")
        else:
            # If coordinates are not found, write NA values
            out_file.write(f"{name}\tNA\tNA\n")

# Open the output file again in read mode to display the results
with open(output_filename, encoding="utf-8") as file:
    # Print the contents to the console for quick verification
    print(file.read())
# Out:
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '00', 'lng': '34.75', 'geonameId': 294640, 'toponymName': 'State of Israel', 'countryId': '294640', 'fcl': 'A', 'population': 8883800, 'countryCode': 'IL', 'name': 'Israel', 'fclName': 'country, state, region,...', 'countryName': 'Israel', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 49, 'geonames': [{'adminCode1': '00', 'lng': '35.20329', 'geonameId': 6254930, 'toponymName': 'Palestine', 'countryId': '6254930', 'fcl': 'A', 'population': 4569087, 'countryCode': 'PS', 'name': 'Palestine', 'fclName': 'country, state, region,...', 'countryName': 'Palestine', 'fcodeName': 'semi-independent political entity', 'adminName1': '', 'lat': '31.92157', 'fcode': 'PCLS'}]}
# {'totalResultsCount': 209, 'geonames': [{'adminCode1': '00', 'lng': '-98.5', 'geonameId': 6252001, 'toponymName': 'United States', 'countryId': '6252001', 'fcl': 'A', 'population': 327167434, 'countryCode': 'US', 'name': 'United States', 'fclName': 'country, state, region,...', 'countryName': 'United States', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39.76', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': 'LA', 'lng': '-92.82265', 'geonameId': 4345667, 'toponymName': 'Welsh', 'countryId': '6252001', 'fcl': 'P', 'population': 3227, 'countryCode': 'US', 'name': 'Welsh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'LA'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Louisiana', 'lat': '30.23604', 'fcode': 'PPL'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '44', 'geonameId': 99237, 'toponymName': 'Republic of Iraq', 'countryId': '99237', 'fcl': 'A', 'population': 38433600, 'countryCode': 'IQ', 'name': 'Iraq', 'fclName': 'country, state, region,...', 'countryName': 'Iraq', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 54, 'geonames': [{'lng': '-116.9579', 'geonameId': 11887751, 'toponymName': 'West', 'countryId': '6252001', 'fcl': 'L', 'population': 77000000, 'countryCode': 'US', 'name': 'West', 'fclName': 'parks,area, ...', 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': '', 'lat': '42.77268', 'fcode': 'RGN'}]}
# {'totalResultsCount': 17, 'geonames': [{'adminCode1': '05', 'lng': '138.51674', 'geonameId': 9258423, 'toponymName': 'Glenelg, South', 'countryId': '2077456', 'fcl': 'L', 'population': 0, 'countryCode': 'AU', 'name': 'Glenelg, South', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'SA'}, 'countryName': 'Australia', 'fcodeName': 'locality', 'adminName1': 'South Australia', 'lat': '-34.98943', 'fcode': 'LCTY'}]}
# {'totalResultsCount': 22, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '02', 'lng': '145.08545', 'geonameId': 2096633, 'toponymName': 'Gulf Province', 'countryId': '2088628', 'fcl': 'A', 'population': 158197, 'countryCode': 'PG', 'name': 'Gulf Province', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'GPK'}, 'countryName': 'Papua New Guinea', 'fcodeName': 'first-order administrative division', 'adminName1': 'Gulf Province', 'lat': '-7.7246', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 57, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 357994, 'toponymName': 'Arab Republic of Egypt', 'countryId': '357994', 'fcl': 'A', 'population': 98423595, 'countryCode': 'EG', 'name': 'Egypt', 'fclName': 'country, state, region,...', 'countryName': 'Egypt', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '27', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1332, 'geonames': [{'adminCode1': 'WE', 'lng': '35.23388', 'geonameId': 7303419, 'toponymName': 'East Jerusalem', 'countryId': '6254930', 'fcl': 'P', 'population': 428304, 'countryCode': 'PS', 'name': 'East Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'section of populated place', 'adminName1': 'West Bank', 'lat': '31.78336', 'fcode': 'PPLX'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Netanyahu&username=yasir.rauf2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 2643, 'geonames': [{'adminCode1': 'FL', 'lng': '-81', 'geonameId': 12217087, 'toponymName': 'South Florida', 'countryId': '6252001', 'fcl': 'L', 'population': 8260000, 'countryCode': 'US', 'name': 'South Florida', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'FL'}, 'countryName': 'United States', 'fcodeName': 'economic region', 'adminName1': 'Florida', 'lat': '26.5', 'fcode': 'RGNE'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '100', 'geonameId': 2017370, 'toponymName': 'Russian Federation', 'countryId': '2017370', 'fcl': 'A', 'population': 144478050, 'countryCode': 'RU', 'name': 'Russia', 'fclName': 'country, state, region,...', 'countryName': 'Russia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '32', 'geonameId': 690791, 'toponymName': 'Ukraine', 'countryId': '690791', 'fcl': 'A', 'population': 44622516, 'countryCode': 'UA', 'name': 'Ukraine', 'fclName': 'country, state, region,...', 'countryName': 'Ukraine', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '49', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 123, 'geonames': [{'adminCode1': '00', 'lng': '105', 'geonameId': 1814991, 'toponymName': 'People’s Republic of China', 'countryId': '1814991', 'fcl': 'A', 'population': 1411778724, 'countryCode': 'CN', 'name': 'China', 'fclName': 'country, state, region,...', 'countryName': 'China', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '112.5', 'geonameId': 1733045, 'toponymName': 'Malaysia', 'countryId': '1733045', 'fcl': 'A', 'population': 31528585, 'countryCode': 'MY', 'name': 'Malaysia', 'fclName': 'country, state, region,...', 'countryName': 'Malaysia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '2.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 23, 'geonames': [{'adminCode1': '00', 'lng': '35', 'geonameId': 298795, 'toponymName': 'Republic of Turkey', 'countryId': '298795', 'fcl': 'A', 'population': 82319724, 'countryCode': 'TR', 'name': 'Türkiye', 'fclName': 'country, state, region,...', 'countryName': 'Türkiye', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 110, 'geonames': [{'adminCode1': '00', 'lng': '36', 'geonameId': 248816, 'toponymName': 'Hashemite Kingdom of Jordan', 'countryId': '248816', 'fcl': 'A', 'population': 9956011, 'countryCode': 'JO', 'name': 'Jordan', 'fclName': 'country, state, region,...', 'countryName': 'Jordan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '31', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 41, 'geonames': [{'adminCode1': '00', 'lng': '-65', 'geonameId': 3923057, 'toponymName': 'Plurinational State of Bolivia', 'countryId': '3923057', 'fcl': 'A', 'population': 11353142, 'countryCode': 'BO', 'name': 'Bolivia', 'fclName': 'country, state, region,...', 'countryName': 'Bolivia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-17', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '73', 'geonameId': 1282028, 'toponymName': 'Republic of Maldives', 'countryId': '1282028', 'fcl': 'A', 'population': 515696, 'countryCode': 'MV', 'name': 'Maldives', 'fclName': 'country, state, region,...', 'countryName': 'Maldives', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '3.2', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '00', 'lng': '17', 'geonameId': 3355338, 'toponymName': 'Republic of Namibia', 'countryId': '3355338', 'fcl': 'A', 'population': 2448255, 'countryCode': 'NA', 'name': 'Namibia', 'fclName': 'country, state, region,...', 'countryName': 'Namibia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '70', 'geonameId': 1168579, 'toponymName': 'Islamic Republic of Pakistan', 'countryId': '1168579', 'fcl': 'A', 'population': 212215030, 'countryCode': 'PK', 'name': 'Pakistan', 'fclName': 'country, state, region,...', 'countryName': 'Pakistan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '30', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 126, 'geonames': [{'adminCode1': '00', 'lng': '-73.25', 'geonameId': 3686110, 'toponymName': 'Republic of Colombia', 'countryId': '3686110', 'fcl': 'A', 'population': 49648685, 'countryCode': 'CO', 'name': 'Colombia', 'fclName': 'country, state, region,...', 'countryName': 'Colombia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '4', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 287, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.30627', 'geonameId': 281124, 'toponymName': 'Khān Yūnis', 'countryId': '6254930', 'fcl': 'P', 'population': 173183, 'countryCode': 'PS', 'name': 'Khan Yunis', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.34018', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 2622, 'geonames': [{'lng': '35.85869', 'geonameId': 6269133, 'name': 'Middle East', 'fclName': 'parks,area, ...', 'toponymName': 'Middle East', 'fcodeName': 'region', 'adminName1': '', 'lat': '33.13906', 'fcl': 'L', 'fcode': 'RGN', 'population': 371400000}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '11', 'lng': '-106.41859', 'geonameId': 12822709, 'toponymName': 'Hague', 'countryId': '6251999', 'fcl': 'A', 'population': 0, 'countryCode': 'CA', 'name': 'Hague', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'SK'}, 'countryName': 'Canada', 'fcodeName': 'second-order administrative division', 'adminName1': 'Saskatchewan', 'lat': '52.51118', 'fcode': 'ADM2'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '00', 'lng': '90', 'geonameId': 1210997, 'toponymName': 'Bangladesh', 'countryId': '1210997', 'fcl': 'A', 'population': 161356039, 'countryCode': 'BD', 'name': 'Bangladesh', 'fclName': 'country, state, region,...', 'countryName': 'Bangladesh', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '24', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '44.44553', 'geonameId': 921929, 'toponymName': 'Union of the Comoros', 'countryId': '921929', 'fcl': 'A', 'population': 832322, 'countryCode': 'KM', 'name': 'Comoros', 'fclName': 'country, state, region,...', 'countryName': 'Comoros', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-12.23333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '00', 'lng': '42.5', 'geonameId': 223816, 'toponymName': 'Republic of Djibouti', 'countryId': '223816', 'fcl': 'A', 'population': 958920, 'countryCode': 'DJ', 'name': 'Djibouti', 'fclName': 'country, state, region,...', 'countryName': 'Djibouti', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '11.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '5.75', 'geonameId': 2750405, 'toponymName': 'Kingdom of the Netherlands', 'countryId': '2750405', 'fcl': 'A', 'population': 17231017, 'countryCode': 'NL', 'name': 'The Netherlands', 'fclName': 'country, state, region,...', 'countryName': 'The Netherlands', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '52.25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 181, 'geonames': [{'adminCode1': '00', 'lng': '-2.69531', 'geonameId': 2635167, 'toponymName': 'United Kingdom of Great Britain and Northern Ireland', 'countryId': '2635167', 'fcl': 'A', 'population': 66488991, 'countryCode': 'GB', 'name': 'United Kingdom', 'fclName': 'country, state, region,...', 'countryName': 'United Kingdom', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '54.75844', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '96', 'geonameId': 1327865, 'toponymName': 'Union of Burma', 'countryId': '1327865', 'fcl': 'A', 'population': 53708395, 'countryCode': 'MM', 'name': 'Myanmar', 'fclName': 'country, state, region,...', 'countryName': 'Myanmar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '21', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '04', 'lng': '35.50157', 'geonameId': 276781, 'toponymName': 'Beirut', 'countryId': '272103', 'fcl': 'P', 'population': 1916100, 'countryCode': 'LB', 'name': 'Beirut', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BA'}, 'countryName': 'Lebanon', 'fcodeName': 'capital of a political entity', 'adminName1': 'Beyrouth', 'lat': '33.89332', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Dahiyeh&username=yasir.rauf2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 76, 'geonames': [{'adminCode1': '00', 'lng': '35.83333', 'geonameId': 272103, 'toponymName': 'Lebanon', 'countryId': '272103', 'fcl': 'A', 'population': 6848925, 'countryCode': 'LB', 'name': 'Lebanon', 'fclName': 'country, state, region,...', 'countryName': 'Lebanon', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '53', 'geonameId': 130758, 'toponymName': 'Islamic Republic of Iran', 'countryId': '130758', 'fcl': 'A', 'population': 81800269, 'countryCode': 'IR', 'name': 'Iran', 'fclName': 'country, state, region,...', 'countryName': 'Iran', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '32', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '47.5', 'geonameId': 69543, 'toponymName': 'Republic of Yemen', 'countryId': '69543', 'fcl': 'A', 'population': 28498687, 'countryCode': 'YE', 'name': 'Yemen', 'fclName': 'country, state, region,...', 'countryName': 'Yemen', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '15.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '05', 'lng': '35.48839', 'geonameId': 276636, 'toponymName': 'Beirut International Airport', 'countryId': '272103', 'fcl': 'S', 'population': 0, 'countryCode': 'LB', 'name': 'Beirut International Airport', 'fclName': 'spot, building, farm', 'adminCodes1': {'ISO3166_2': 'JL'}, 'countryName': 'Lebanon', 'fcodeName': 'airport', 'adminName1': 'Mont-Liban', 'lat': '33.82093', 'fcode': 'AIRP'}]}
# {'totalResultsCount': 1970, 'geonames': [{'adminCode1': '01', 'lng': '-113.802', 'geonameId': 6118158, 'toponymName': 'Red Deer', 'countryId': '6251999', 'fcl': 'P', 'population': 73593, 'countryCode': 'CA', 'name': 'Red Deer', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '52.26682', 'fcode': 'PPL'}]}
# {'totalResultsCount': 29, 'geonames': [{'lng': '21.09375', 'geonameId': 6255146, 'name': 'Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Africa', 'fcodeName': 'continent', 'adminName1': '', 'lat': '7.1881', 'fcl': 'L', 'fcode': 'CONT', 'population': 1031833000}]}
# {'totalResultsCount': 234, 'geonames': [{'lng': '48', 'geonameId': 80303, 'name': 'Gulf of Aden', 'fclName': 'stream, lake, ...', 'toponymName': 'Gulf of Aden', 'fcodeName': 'gulf', 'adminName1': '', 'lat': '12', 'fcl': 'H', 'fcode': 'GULF', 'population': 0}]}
# {'totalResultsCount': 418, 'geonames': [{'adminCode1': 'CO', 'lng': '-108.02785', 'geonameId': 5416048, 'toponymName': 'Cape of Good Hope', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Cape of Good Hope', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'CO'}, 'countryName': 'United States', 'fcodeName': 'cliff(s)', 'adminName1': 'Colorado', 'lat': '37.52777', 'fcode': 'CLF'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '103.8', 'geonameId': 1880251, 'toponymName': 'Republic of Singapore', 'countryId': '1880251', 'fcl': 'A', 'population': 5638676, 'countryCode': 'SG', 'name': 'Singapore', 'fclName': 'country, state, region,...', 'countryName': 'Singapore', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '1.36667', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 25, 'geonames': [{'lng': '19.33', 'geonameId': 12217088, 'name': 'Mediterranean Basin', 'fclName': 'parks,area, ...', 'toponymName': 'Mediterranean Basin', 'fcodeName': 'economic region', 'adminName1': '', 'lat': '35.78', 'fcl': 'L', 'fcode': 'RGNE', 'population': 506090000}]}
# {'totalResultsCount': 3515, 'geonames': [{'lng': '70', 'geonameId': 1545739, 'name': 'Indian Ocean', 'fclName': 'stream, lake, ...', 'toponymName': 'Indian Ocean', 'fcodeName': 'ocean', 'adminName1': '', 'lat': '-10', 'fcl': 'H', 'fcode': 'OCN', 'population': 0}]}
# {'totalResultsCount': 14, 'geonames': [{'lng': '9.14062', 'geonameId': 6255148, 'name': 'Europe', 'fclName': 'parks,area, ...', 'toponymName': 'Europe', 'fcodeName': 'continent', 'adminName1': '', 'lat': '48.69096', 'fcl': 'L', 'fcode': 'CONT', 'population': 741000000}]}
# {'totalResultsCount': 44, 'geonames': [{'lng': '89.29688', 'geonameId': 6255147, 'name': 'Asia', 'fclName': 'parks,area, ...', 'toponymName': 'Asia', 'fcodeName': 'continent', 'adminName1': '', 'lat': '29.84064', 'fcl': 'L', 'fcode': 'CONT', 'population': 3812366000}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '-4', 'geonameId': 2510769, 'toponymName': 'Kingdom of Spain', 'countryId': '2510769', 'fcl': 'A', 'population': 46723749, 'countryCode': 'ES', 'name': 'Spain', 'fclName': 'country, state, region,...', 'countryName': 'Spain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '40', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 160, 'geonames': [{'adminCode1': '00', 'lng': '-113.64258', 'geonameId': 6251999, 'toponymName': 'Canada', 'countryId': '6251999', 'fcl': 'A', 'population': 37058856, 'countryCode': 'CA', 'name': 'Canada', 'fclName': 'country, state, region,...', 'countryName': 'Canada', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '60.10867', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '135', 'geonameId': 2077456, 'toponymName': 'Commonwealth of Australia', 'countryId': '2077456', 'fcl': 'A', 'population': 24992369, 'countryCode': 'AU', 'name': 'Australia', 'fclName': 'country, state, region,...', 'countryName': 'Australia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '-25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '10.5', 'geonameId': 2921044, 'toponymName': 'Federal Republic of Germany', 'countryId': '2921044', 'fcl': 'A', 'population': 82927922, 'countryCode': 'DE', 'name': 'Germany', 'fclName': 'country, state, region,...', 'countryName': 'Germany', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '51.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '00', 'lng': '12.83333', 'geonameId': 3175395, 'toponymName': 'Italian Republic', 'countryId': '3175395', 'fcl': 'A', 'population': 60431283, 'countryCode': 'IT', 'name': 'Italy', 'fclName': 'country, state, region,...', 'countryName': 'Italy', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '42.83333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': '00', 'lng': '8.01427', 'geonameId': 2658434, 'toponymName': 'Switzerland', 'countryId': '2658434', 'fcl': 'A', 'population': 8516543, 'countryCode': 'CH', 'name': 'Switzerland', 'fclName': 'country, state, region,...', 'countryName': 'Switzerland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.00016', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '00', 'lng': '26', 'geonameId': 660013, 'toponymName': 'Republic of Finland', 'countryId': '660013', 'fcl': 'A', 'population': 5518050, 'countryCode': 'FI', 'name': 'Finland', 'fclName': 'country, state, region,...', 'countryName': 'Finland', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '64', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': '00', 'lng': '26', 'geonameId': 453733, 'toponymName': 'Republic of Estonia', 'countryId': '453733', 'fcl': 'A', 'population': 1320884, 'countryCode': 'EE', 'name': 'Estonia', 'fclName': 'country, state, region,...', 'countryName': 'Estonia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '59', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 19, 'geonames': [{'adminCode1': '00', 'lng': '139.75309', 'geonameId': 1861060, 'toponymName': 'Japan', 'countryId': '1861060', 'fcl': 'A', 'population': 126529100, 'countryCode': 'JP', 'name': 'Japan', 'fclName': 'country, state, region,...', 'countryName': 'Japan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35.68536', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '13.33333', 'geonameId': 2782113, 'toponymName': 'Republic of Austria', 'countryId': '2782113', 'fcl': 'A', 'population': 8847037, 'countryCode': 'AT', 'name': 'Austria', 'fclName': 'country, state, region,...', 'countryName': 'Austria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '47.33333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '00', 'lng': '25', 'geonameId': 798549, 'toponymName': 'România', 'countryId': '798549', 'fcl': 'A', 'population': 19473936, 'countryCode': 'RO', 'name': 'Romania', 'fclName': 'country, state, region,...', 'countryName': 'Romania', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '46', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 2604, 'geonames': [{'adminCode1': '10375968', 'lng': '-81.39281', 'geonameId': 3580477, 'toponymName': 'West Bay', 'countryId': '3580718', 'fcl': 'P', 'population': 15335, 'countryCode': 'KY', 'name': 'West Bay', 'fclName': 'city, village,...', 'countryName': 'Cayman Islands', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'West Bay', 'lat': '19.38197', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '38', 'geonameId': 163843, 'toponymName': 'Syrian Arab Republic', 'countryId': '163843', 'fcl': 'A', 'population': 16906283, 'countryCode': 'SY', 'name': 'Syria', 'fclName': 'country, state, region,...', 'countryName': 'Syria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '35', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=October7&username=yasir.rauf2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 108, 'geonames': [{'adminCode1': '06', 'lng': '35.21633', 'geonameId': 281184, 'toponymName': 'Jerusalem', 'countryId': '294640', 'fcl': 'P', 'population': 971800, 'countryCode': 'IL', 'name': 'Jerusalem', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JM'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Jerusalem', 'lat': '31.76904', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.17631', 'geonameId': 4990510, 'toponymName': 'Dearborn', 'countryId': '6252001', 'fcl': 'P', 'population': 95171, 'countryCode': 'US', 'name': 'Dearborn', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Michigan', 'lat': '42.32226', 'fcode': 'PPL'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': 'MI', 'lng': '-85.50033', 'geonameId': 5001836, 'toponymName': 'Michigan', 'countryId': '6252001', 'fcl': 'A', 'population': 9883360, 'countryCode': 'US', 'name': 'Michigan', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Michigan', 'lat': '44.25029', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 1158, 'geonames': [{'adminCode1': 'ME', 'lng': '-70.2331', 'geonameId': 4970921, 'toponymName': 'Mackworth Island', 'countryId': '6252001', 'fcl': 'T', 'population': 0, 'countryCode': 'US', 'name': 'Mackworth Island', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': 'ME'}, 'countryName': 'United States', 'fcodeName': 'island', 'adminName1': 'Maine', 'lat': '43.68897', 'fcode': 'ISL'}]}
# {'totalResultsCount': 1092, 'geonames': [{'adminCode1': '47', 'lng': '127.94581', 'geonameId': 1854346, 'toponymName': 'Okinawa', 'countryId': '1861060', 'fcl': 'T', 'population': 1301000, 'countryCode': 'JP', 'name': 'Okinawa', 'fclName': 'mountain,hill,rock,... ', 'adminCodes1': {'ISO3166_2': '47'}, 'countryName': 'Japan', 'fcodeName': 'island', 'adminName1': 'Okinawa', 'lat': '26.50687', 'fcode': 'ISL'}]}
# {'totalResultsCount': 1300, 'geonames': [{'adminCode1': 'MI', 'lng': '-86.75698', 'geonameId': 5001835, 'toponymName': 'Lake Michigan', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Michigan', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Michigan', 'lat': '44.00778', 'fcode': 'LK'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '00', 'lng': '66', 'geonameId': 1149361, 'toponymName': 'Islamic Republic of Afghanistan', 'countryId': '1149361', 'fcl': 'A', 'population': 37172386, 'countryCode': 'AF', 'name': 'Afghanistan', 'fclName': 'country, state, region,...', 'countryName': 'Afghanistan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '33', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 56, 'geonames': [{'adminCode1': 'TX', 'lng': '-99.25061', 'geonameId': 4736286, 'toponymName': 'Texas', 'countryId': '6252001', 'fcl': 'A', 'population': 22875689, 'countryCode': 'US', 'name': 'Texas', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'TX'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Texas', 'lat': '31.25044', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 235, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.49514', 'geonameId': 281145, 'toponymName': 'Bayt Lāhyā', 'countryId': '6254930', 'fcl': 'P', 'population': 56919, 'countryCode': 'PS', 'name': 'Beit Lahia', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.5464', 'fcode': 'PPL'}]}
# {'totalResultsCount': 4, 'geonames': [{'adminCode1': '12', 'lng': '36.63393', 'geonameId': 169389, 'toponymName': 'Idlib', 'countryId': '163843', 'fcl': 'P', 'population': 128840, 'countryCode': 'SY', 'name': 'Idlib', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ID'}, 'countryName': 'Syria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Idlib', 'lat': '35.93062', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 11, 'geonames': [{'adminCode1': '07', 'lng': '7.82089', 'geonameId': 2911240, 'toponymName': 'Hamm', 'countryId': '2921044', 'fcl': 'P', 'population': 178967, 'countryCode': 'DE', 'name': 'Hamm', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'NW'}, 'countryName': 'Germany', 'fcodeName': 'populated place', 'adminName1': 'North Rhine-Westphalia', 'lat': '51.68033', 'fcode': 'PPL'}]}
# {'totalResultsCount': 325, 'geonames': [{'adminCode1': '05', 'lng': '34.78057', 'geonameId': 293397, 'toponymName': 'Tel Aviv', 'countryId': '294640', 'fcl': 'P', 'population': 432892, 'countryCode': 'IL', 'name': 'Tel Aviv', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'TA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Tel Aviv', 'lat': '32.08088', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 425, 'geonames': [{'adminCode1': 'WA', 'lng': '-120.50147', 'geonameId': 5815135, 'toponymName': 'Washington', 'countryId': '6252001', 'fcl': 'A', 'population': 6271775, 'countryCode': 'US', 'name': 'Washington', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'WA'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Washington', 'lat': '47.50012', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 56, 'geonames': [{'adminCode1': '11', 'lng': '31.24967', 'geonameId': 360630, 'toponymName': 'Cairo', 'countryId': '357994', 'fcl': 'P', 'population': 9606916, 'countryCode': 'EG', 'name': 'Cairo', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'C'}, 'countryName': 'Egypt', 'fcodeName': 'capital of a political entity', 'adminName1': 'Cairo', 'lat': '30.06263', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': '01', 'lng': '51.53096', 'geonameId': 290030, 'toponymName': 'Doha', 'countryId': '289688', 'fcl': 'P', 'population': 344939, 'countryCode': 'QA', 'name': 'Doha', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DA'}, 'countryName': 'Qatar', 'fcodeName': 'capital of a political entity', 'adminName1': 'Baladīyat ad Dawḩah', 'lat': '25.28545', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 2, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.3925', 'geonameId': 281109, 'toponymName': 'An Nuşayrāt', 'countryId': '6254930', 'fcl': 'P', 'population': 36123, 'countryCode': 'PS', 'name': 'An Nuşayrāt', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.44861', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1627, 'geonames': [{'lng': '24.69727', 'geonameId': 7729886, 'name': 'Central Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Central Africa', 'fcodeName': 'region', 'adminName1': '', 'lat': '-2.02107', 'fcl': 'L', 'fcode': 'RGN', 'population': 129400000}]}
# {'totalResultsCount': 235, 'geonames': [{'adminCode1': '07', 'lng': '40.14084', 'geonameId': 170794, 'toponymName': 'Deir ez-Zor', 'countryId': '163843', 'fcl': 'P', 'population': 271800, 'countryCode': 'SY', 'name': 'Dayr az Zawr', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DY'}, 'countryName': 'Syria', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Deir ez-Zor', 'lat': '35.33588', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 14, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.24357', 'geonameId': 281102, 'toponymName': 'Rafaḩ', 'countryId': '6254930', 'fcl': 'P', 'population': 126305, 'countryCode': 'PS', 'name': 'Rafah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.29722', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 27, 'geonames': [{'adminCode1': '00', 'lng': '79', 'geonameId': 1269750, 'toponymName': 'Republic of India', 'countryId': '1269750', 'fcl': 'A', 'population': 1352617328, 'countryCode': 'IN', 'name': 'India', 'fclName': 'country, state, region,...', 'countryName': 'India', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1125, 'geonames': [{'adminCode1': '07', 'lng': '77.2148', 'geonameId': 1261481, 'toponymName': 'New Delhi', 'countryId': '1269750', 'fcl': 'P', 'population': 317797, 'countryCode': 'IN', 'name': 'New Delhi', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'DL'}, 'countryName': 'India', 'fcodeName': 'capital of a political entity', 'adminName1': 'Delhi', 'lat': '28.62137', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 45, 'geonames': [{'adminCode1': '00', 'lng': '79', 'geonameId': 1269750, 'toponymName': 'Republic of India', 'countryId': '1269750', 'fcl': 'A', 'population': 1352617328, 'countryCode': 'IN', 'name': 'India', 'fclName': 'country, state, region,...', 'countryName': 'India', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '22', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1422, 'geonames': [{'lng': '-100.54688', 'geonameId': 6255149, 'name': 'North America', 'fclName': 'parks,area, ...', 'toponymName': 'North America', 'fcodeName': 'continent', 'adminName1': '', 'lat': '46.07323', 'fcl': 'L', 'fcode': 'CONT', 'population': 580000000}]}
# {'totalResultsCount': 2557, 'geonames': [{'lng': '9.97559', 'geonameId': 7729887, 'name': 'Northern Africa', 'fclName': 'parks,area, ...', 'toponymName': 'Northern Africa', 'fcodeName': 'region', 'adminName1': '', 'lat': '32.95337', 'fcl': 'L', 'fcode': 'RGN', 'population': 210800000}]}
# {'totalResultsCount': 24, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': 'DC', 'lng': '-77.00025', 'geonameId': 4138106, 'toponymName': 'District of Columbia', 'countryId': '6252001', 'fcl': 'A', 'population': 552433, 'countryCode': 'US', 'name': 'District of Columbia', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'DC'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'District of Columbia', 'lat': '38.91706', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 138, 'geonames': [{'adminCode1': '14', 'lng': '31.60823', 'geonameId': 354820, 'toponymName': 'Kafr Abū Musallam', 'countryId': '357994', 'fcl': 'P', 'population': 0, 'countryCode': 'EG', 'name': 'Kafr Abū Musallam', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'SHR'}, 'countryName': 'Egypt', 'fcodeName': 'populated place', 'adminName1': 'Sharqia', 'lat': '30.486', 'fcode': 'PPL'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '01', 'lng': '34.28459', 'geonameId': 294481, 'toponymName': 'Kerem Shalom', 'countryId': '294640', 'fcl': 'P', 'population': 183, 'countryCode': 'IL', 'name': 'Kerem Shalom', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'D'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Southern District', 'lat': '31.22777', 'fcode': 'PPL'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '00', 'lng': '22', 'geonameId': 390903, 'toponymName': 'Hellenic Republic', 'countryId': '390903', 'fcl': 'A', 'population': 10727668, 'countryCode': 'GR', 'name': 'Greece', 'fclName': 'country, state, region,...', 'countryName': 'Greece', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '39', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 531, 'geonames': [{'adminCode1': '00', 'lng': '54.5', 'geonameId': 290557, 'toponymName': 'United Arab Emirates', 'countryId': '290557', 'fcl': 'A', 'population': 9630959, 'countryCode': 'AE', 'name': 'United Arab Emirates', 'fclName': 'country, state, region,...', 'countryName': 'United Arab Emirates', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '23.75', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'WE', 'lng': '35.20422', 'geonameId': 282239, 'toponymName': 'Ramallah', 'countryId': '6254930', 'fcl': 'P', 'population': 24599, 'countryCode': 'PS', 'name': 'Ramallah', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'West Bank', 'lat': '31.89964', 'fcode': 'PPL'}]}
# {'totalResultsCount': 54, 'geonames': [{'adminCode1': 'GE', 'lng': '6.14569', 'geonameId': 2660646, 'toponymName': 'Genève', 'countryId': '2658434', 'fcl': 'P', 'population': 183981, 'countryCode': 'CH', 'name': 'Geneva', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'GE'}, 'countryName': 'Switzerland', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Geneva', 'lat': '46.20222', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 78, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.46672', 'geonameId': 281133, 'toponymName': 'Gaza', 'countryId': '6254930', 'fcl': 'P', 'population': 410000, 'countryCode': 'PS', 'name': 'Gaza', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Gaza Strip', 'lat': '31.50161', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 8, 'geonames': [{'adminCode1': '02', 'lng': '11.57549', 'geonameId': 2867714, 'toponymName': 'Munich', 'countryId': '2921044', 'fcl': 'P', 'population': 1260391, 'countryCode': 'DE', 'name': 'Munich', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'BY'}, 'countryName': 'Germany', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Bavaria', 'lat': '48.13743', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': '04', 'lng': '34.9885', 'geonameId': 294801, 'toponymName': 'Haifa', 'countryId': '294640', 'fcl': 'P', 'population': 285316, 'countryCode': 'IL', 'name': 'Haifa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'HA'}, 'countryName': 'Israel', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Haifa', 'lat': '32.81841', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '06', 'lng': '35.37148', 'geonameId': 268064, 'toponymName': 'Sidon', 'countryId': '272103', 'fcl': 'P', 'population': 163554, 'countryCode': 'LB', 'name': 'Sidon', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'JA'}, 'countryName': 'Lebanon', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'South Governorate', 'lat': '33.55751', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 5, 'geonames': [{'adminCode1': '42', 'lng': '59.97553', 'geonameId': 117741, 'toponymName': 'Salāmeh', 'countryId': '130758', 'fcl': 'P', 'population': 0, 'countryCode': 'IR', 'name': 'Salāmeh', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '09'}, 'countryName': 'Iran', 'fcodeName': 'populated place', 'adminName1': 'Razavi Khorasan', 'lat': '34.74384', 'fcode': 'PPL'}]}
# {'totalResultsCount': 15, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.04575', 'geonameId': 4990729, 'toponymName': 'Detroit', 'countryId': '6252001', 'fcl': 'P', 'population': 677116, 'countryCode': 'US', 'name': 'Detroit', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Michigan', 'lat': '42.33143', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 291, 'geonames': [{'adminCode1': 'MI', 'lng': '-83.71087', 'geonameId': 12111046, 'toponymName': 'Southeast Michigan', 'countryId': '6252001', 'fcl': 'L', 'population': 270000, 'countryCode': 'US', 'name': 'Southeast Michigan', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'MI'}, 'countryName': 'United States', 'fcodeName': 'region', 'adminName1': 'Michigan', 'lat': '43.96102', 'fcode': 'RGN'}]}
# {'totalResultsCount': 309, 'geonames': [{'adminCode1': '00', 'lng': '45', 'geonameId': 102358, 'toponymName': 'Kingdom of Saudi Arabia', 'countryId': '102358', 'fcl': 'A', 'population': 33699947, 'countryCode': 'SA', 'name': 'Saudi Arabia', 'fclName': 'country, state, region,...', 'countryName': 'Saudi Arabia', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '01', 'lng': '54.1', 'geonameId': 291804, 'toponymName': 'Jarrah', 'countryId': '290557', 'fcl': 'L', 'population': 0, 'countryCode': 'AE', 'name': 'Jarrah', 'fclName': 'parks,area, ...', 'adminCodes1': {'ISO3166_2': 'AZ'}, 'countryName': 'United Arab Emirates', 'fcodeName': 'oasis(-es)', 'adminName1': 'Abu Dhabi', 'lat': '24.05', 'fcode': 'OAS'}]}
# {'totalResultsCount': 288, 'geonames': [{'adminCode1': '00', 'lng': '175', 'geonameId': 2180400, 'toponymName': 'Waiheke County', 'countryId': '2186224', 'fcl': 'A', 'population': 0, 'countryCode': 'NZ', 'name': 'Waiheke County', 'fclName': 'country, state, region,...', 'countryName': 'New Zealand', 'fcodeName': 'historical first-order administrative division', 'adminName1': '', 'lat': '-36.75', 'fcode': 'ADM1H'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': 'MN', 'lng': '-94.25055', 'geonameId': 5037779, 'toponymName': 'Minnesota', 'countryId': '6252001', 'fcl': 'A', 'population': 5141953, 'countryCode': 'US', 'name': 'Minnesota', 'fclName': 'country, state, region,...', 'adminCodes1': {'ISO3166_2': 'MN'}, 'countryName': 'United States', 'fcodeName': 'first-order administrative division', 'adminName1': 'Minnesota', 'lat': '46.25024', 'fcode': 'ADM1'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': '10', 'lng': '-73.58781', 'geonameId': 6077243, 'toponymName': 'Montréal', 'countryId': '6251999', 'fcl': 'P', 'population': 1762949, 'countryCode': 'CA', 'name': 'Montreal', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'QC'}, 'countryName': 'Canada', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'Quebec', 'lat': '45.50884', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 304, 'geonames': [{'adminCode1': 'ENG', 'lng': '-0.75583', 'geonameId': 2642465, 'toponymName': 'Milton Keynes', 'countryId': '2635167', 'fcl': 'P', 'population': 256385, 'countryCode': 'GB', 'name': 'Milton Keynes', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ENG'}, 'countryName': 'United Kingdom', 'fcodeName': 'seat of a second-order administrative division', 'adminName1': 'England', 'lat': '52.04172', 'fcode': 'PPLA2'}]}
# {'totalResultsCount': 3, 'geonames': [{'adminCode1': 'GZ', 'lng': '34.48347', 'geonameId': 281129, 'toponymName': 'Jabālyā', 'countryId': '6254930', 'fcl': 'P', 'population': 168568, 'countryCode': 'PS', 'name': 'Jabalia', 'fclName': 'city, village,...', 'adminCodes1': {}, 'countryName': 'Palestine', 'fcodeName': 'populated place', 'adminName1': 'Gaza Strip', 'lat': '31.5272', 'fcode': 'PPL'}]}
# {'totalResultsCount': 30, 'geonames': [{'adminCode1': '08', 'lng': '-75.69812', 'geonameId': 6094817, 'toponymName': 'Ottawa', 'countryId': '6251999', 'fcl': 'P', 'population': 812129, 'countryCode': 'CA', 'name': 'Ottawa', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ON'}, 'countryName': 'Canada', 'fcodeName': 'capital of a political entity', 'adminName1': 'Ontario', 'lat': '45.41117', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 33, 'geonames': [{'adminCode1': '08', 'lng': '-79.39864', 'geonameId': 6167865, 'toponymName': 'Toronto', 'countryId': '6251999', 'fcl': 'P', 'population': 2600000, 'countryCode': 'CA', 'name': 'Toronto', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'ON'}, 'countryName': 'Canada', 'fcodeName': 'seat of a first-order administrative division', 'adminName1': 'Ontario', 'lat': '43.70643', 'fcode': 'PPLA'}]}
# {'totalResultsCount': 6, 'geonames': [{'adminCode1': '01', 'lng': '-114.08529', 'geonameId': 5913490, 'toponymName': 'Calgary', 'countryId': '6251999', 'fcl': 'P', 'population': 1019942, 'countryCode': 'CA', 'name': 'Calgary', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'AB'}, 'countryName': 'Canada', 'fcodeName': 'populated place', 'adminName1': 'Alberta', 'lat': '51.05011', 'fcode': 'PPL'}]}
# {'totalResultsCount': 10, 'geonames': [{'adminCode1': '00', 'lng': '-10', 'geonameId': 2542007, 'toponymName': 'Kingdom of Morocco', 'countryId': '2542007', 'fcl': 'A', 'population': 36029138, 'countryCode': 'MA', 'name': 'Morocco', 'fclName': 'country, state, region,...', 'countryName': 'Morocco', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 96, 'geonames': [{'adminCode1': '04', 'lng': '-6.83255', 'geonameId': 2538475, 'toponymName': 'Rabat', 'countryId': '2542007', 'fcl': 'P', 'population': 1655753, 'countryCode': 'MA', 'name': 'Rabat', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '04'}, 'countryName': 'Morocco', 'fcodeName': 'capital of a political entity', 'adminName1': 'Rabat-Salé-Kénitra', 'lat': '34.01325', 'fcode': 'PPLC'}]}
# {'totalResultsCount': 7, 'geonames': [{'adminCode1': '00', 'lng': '50.55', 'geonameId': 290291, 'toponymName': 'Kingdom of Bahrain', 'countryId': '290291', 'fcl': 'A', 'population': 1569439, 'countryCode': 'BH', 'name': 'Bahrain', 'fclName': 'country, state, region,...', 'countryName': 'Bahrain', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '26.03333', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 36, 'geonames': [{'adminCode1': '00', 'lng': '30', 'geonameId': 366755, 'toponymName': 'Republic of the Sudan', 'countryId': '366755', 'fcl': 'A', 'population': 41801533, 'countryCode': 'SD', 'name': 'Sudan', 'fclName': 'country, state, region,...', 'countryName': 'Sudan', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '16', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 715, 'geonames': [{'adminCode1': '00', 'lng': '105.83224', 'geonameId': 11497302, 'toponymName': 'Western Region', 'countryId': '1562822', 'fcl': 'L', 'population': 17080000, 'countryCode': 'VN', 'name': 'Western Region', 'fclName': 'parks,area, ...', 'countryName': 'Vietnam', 'fcodeName': 'region', 'adminName1': '', 'lat': '10.01211', 'fcode': 'RGN'}]}
# {'totalResultsCount': 9, 'geonames': [{'adminCode1': '00', 'lng': '3', 'geonameId': 2589581, 'toponymName': "People's Democratic Republic of Algeria", 'countryId': '2589581', 'fcl': 'A', 'population': 42228429, 'countryCode': 'DZ', 'name': 'Algeria', 'fclName': 'country, state, region,...', 'countryName': 'Algeria', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '28', 'fcode': 'PCLI'}]}
# ...
# {'totalResultsCount': 18, 'geonames': [{'adminCode1': '15', 'lng': '48.45684', 'geonameId': 132147, 'toponymName': 'Ḩamād', 'countryId': '130758', 'fcl': 'P', 'population': 0, 'countryCode': 'IR', 'name': 'Ḩamād', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': '06'}, 'countryName': 'Iran', 'fcodeName': 'populated place', 'adminName1': 'Khuzestan', 'lat': '31.40307', 'fcode': 'PPL'}]}
# {'totalResultsCount': 299, 'geonames': [{'adminCode1': '00', 'lng': '51.25', 'geonameId': 289688, 'toponymName': 'State of Qatar', 'countryId': '289688', 'fcl': 'A', 'population': 2781677, 'countryCode': 'QA', 'name': 'Qatar', 'fclName': 'country, state, region,...', 'countryName': 'Qatar', 'fcodeName': 'independent political entity', 'adminName1': '', 'lat': '25.5', 'fcode': 'PCLI'}]}
# {'totalResultsCount': 0, 'geonames': []}
# No results found for your API call http://api.geonames.org/searchJSON?q=Qffd&username=yasir.rauf2&fuzzy=0&maxRows=1&isNameRequired=True
# {'totalResultsCount': 364, 'geonames': [{'adminCode1': 'KY', 'lng': '-85.7319', 'geonameId': 4297664, 'toponymName': 'Lebanon Junction', 'countryId': '6252001', 'fcl': 'P', 'population': 1917, 'countryCode': 'US', 'name': 'Lebanon Junction', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'KY'}, 'countryName': 'United States', 'fcodeName': 'populated place', 'adminName1': 'Kentucky', 'lat': '37.83451', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '03', 'lng': '35.4546', 'geonameId': 293180, 'toponymName': 'Yir’on', 'countryId': '294640', 'fcl': 'P', 'population': 404, 'countryCode': 'IL', 'name': 'Yir’on', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'Z'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Northern District', 'lat': '33.07757', 'fcode': 'PPL'}]}
# {'totalResultsCount': 1, 'geonames': [{'adminCode1': '03', 'lng': '35.47228', 'geonameId': 295598, 'toponymName': 'Avivim', 'countryId': '294640', 'fcl': 'P', 'population': 471, 'countryCode': 'IL', 'name': 'Avivim', 'fclName': 'city, village,...', 'adminCodes1': {'ISO3166_2': 'Z'}, 'countryName': 'Israel', 'fcodeName': 'populated place', 'adminName1': 'Northern District', 'lat': '33.08892', 'fcode': 'PPL'}]}
# {'totalResultsCount': 40, 'geonames': [{'adminCode1': 'MA', 'lng': '-70.27889', 'geonameId': 4940697, 'toponymName': 'Israel Pond', 'countryId': '6252001', 'fcl': 'H', 'population': 0, 'countryCode': 'US', 'name': 'Israel Pond', 'fclName': 'stream, lake, ...', 'adminCodes1': {'ISO3166_2': 'MA'}, 'countryName': 'United States', 'fcodeName': 'lake', 'adminName1': 'Massachusetts', 'lat': '41.68181', 'fcode': 'LK'}]}
# Name	Latitude	Longitude
# Israel	31.5	34.75
# Gaza	31.50161	34.46672
# Palestine	31.92157	35.20329
# United States	39.76	-98.5
# Welch	30.23604	-92.82265
# Iraq	33	44
# West	42.77268	-116.9579
# Global South	-34.98943	138.51674
# Qatar	25.5	51.25
# Gulf	-7.7246	145.08545
# Egypt	27	30
# East Jerusalem	31.78336	35.23388
# Netanyahu	NA	NA
# Gaza Strip	31.50161	34.46672
# South Africa	26.5	-81
# Russia	60	100
# Ukraine	49	32
# China	35	105
# Malaysia	2.5	112.5
# Turkey	39	35
# Jordan	31	36
# Bolivia	-17	-65
# Maldives	3.2	73
# Namibia	-22	17
# Pakistan	30	70
# Columbia	4	-73.25
# Khan Younis	31.34018	34.30627
# Middle East	33.13906	35.85869
# Hague	52.51118	-106.41859
# Bangladesh	24	90
# Comoros	-12.23333	44.44553
# Djibouti	11.83333	42.5
# Netherlands	52.25	5.75
# United Kingdom	54.75844	-2.69531
# Myanmar	21	96
# Beirut	33.89332	35.50157
# Dahiyeh	NA	NA
# Lebanon	33.83333	35.83333
# Iran	32	53
# Yemen	15.5	47.5
# Beirut Shatila	33.82093	35.48839
# Red Sea	52.26682	-113.802
# Africa	7.1881	21.09375
# Gulf Of Aden	12	48
# Cape Of Good Hope	37.52777	-108.02785
# Singapore	1.36667	103.8
# Mediterranean	35.78	19.33
# Indian Ocean	-10	70
# Europe	48.69096	9.14062
# Asia	29.84064	89.29688
# Spain	40	-4
# Canada	60.10867	-113.64258
# Australia	-25	135
# Germany	51.5	10.5
# Italy	42.83333	12.83333
# Switzerland	47.00016	8.01427
# Finland	64	26
# Estonia	59	26
# Japan	35.68536	139.75309
# Austria	47.33333	13.33333
# Romania	46	25
# West Bank	19.38197	-81.39281
# Syria	35	38
# October7	NA	NA
# Jerusalem	31.76904	35.21633
# Dearborn	42.32226	-83.17631
# Michigan	44.25029	-85.50033
# Mackinac Island	43.68897	-70.2331
# Great Lakes	26.50687	127.94581
# Lake Michigan	44.00778	-86.75698
# Afghanistan	33	66
# Texas	31.25044	-99.25061
# Beit Nabala	31.5464	34.49514
# Idlib	35.93062	36.63393
# Hamas	51.68033	7.82089
# Tel Aviv	32.08088	34.78057
# Washington	47.50012	-120.50147
# Cairo	30.06263	31.24967
# Doha	25.28545	51.53096
# Nuseirat	31.44861	34.3925
# Central Gaza Strip	-2.02107	24.69727
# Deir Elbalah	35.33588	40.14084
# Rafah	31.29722	34.24357
# India	22	79
# New Delhi	28.62137	77.2148
# India Basmati	22	79
# North America	46.07323	-100.54688
# North Africa	32.95337	9.97559
# Arabian Sea	25	45
# Dc	38.91706	-77.00025
# Karem Abu Salem	30.486	31.60823
# Kerem Shalom	31.22777	34.28459
# Greece	39	22
# Saudi Arabia	25	45
# United Arab Emirates	23.75	54.5
# Ramallah	31.89964	35.20422
# Geneva	46.20222	6.14569
# Gaza City	31.50161	34.46672
# Munich	48.13743	11.57549
# Haifa	32.81841	34.9885
# Sidon	33.55751	35.37148
# Salameh	34.74384	59.97553
# Detroit	42.33143	-83.04575
# Southeast Michigan	43.96102	-83.71087
# Arab America	25	45
# Jarrah	24.05	54.1
# Wayne County	-36.75	175
# Minnesota	46.25024	-94.25055
# Montreal	45.50884	-73.58781
# Milton Ontario	52.04172	-0.75583
# Jabalia	31.5272	34.48347
# Ottawa	45.41117	-75.69812
# Toronto	43.70643	-79.39864
# Calgary	51.05011	-114.08529
# Morocco	28.5	-10
# Rabat	34.01325	-6.83255
# Bahrain	26.03333	50.55
# Sudan	16	30
# Western Sahara	10.01211	105.83224
# Algeria	28	3
# Marrakesh	31.63416	-7.99994
# Maghreb	30	5
# Bethlehem	40.62593	-75.37046
# Nairoukh	NA	NA
# Shawawra	NA	NA
# Marshall Islands	7.113	171.236
# Aden	12.77944	45.03667
# Bab Almandeb Strait	30.73222	56.7175
# Hodeidah	14.79781	42.95452
# Al Maniya	41	20
# Westbank	49.83521	-119.62532
# Melbourne Australia	-37.67333	144.84333
# Melbourne	-37.814	144.96332
# Sandridge Beach	-37.83931	144.91747
# Zim Ganges	45.06873	-83.54131
# Sydney	-33.86785	151.20732
# Brisbane	-27.46794	153.02809
# Yemen Coast	12.79891	45.03313
# Alborz	36.01117	50.80956
# Damascus	33.5102	36.29128
# Tehran	35.69439	51.42151
# Beit Lahiya	31.5464	34.49514
# Shujayea	NA	NA
# Alsaftawi	NA	NA
# Houthis	NA	NA
# Babelmandeb Strait	6.8127	122.0236
# Sanaa	15.35472	44.20667
# Taiz	13.57952	44.02091
# Dhamar	14.54274	44.40514
# Albayda	18.86139	42.07078
# Saada	16.94021	43.76393
# Dublin	53.33306	-6.24889
# Moscow	55.75222	37.61556
# Bureij	31.43944	34.40306
# Almahatta	NA	NA
# Belgium	50.75	4.5
# Pretoria	-25.74486	28.18783
# Hong Kong	22.27832	114.17469
# Denmark	56	10
# New Zealand	-42	174
# South Korea	36.5	127.75
# France	46	2
# Alwalaja	NA	NA
# Area C	-25.55132	-54.61622
# Gilo	-7.45	-40.83333
# Har Gilo	31.72119	35.1724
# El Arish	31.13159	33.79844
# Norway	62	10
# Strip	-27.51667	27.05
# Supernova	NA	NA
# Mexico	23	-102
# Chile	-30	-71
# Altanf	NA	NA
# Amman	31.95522	35.94503
# Hashemite Kingdom Of Jordan	31	36
# Baghdad	33.34058	44.40088
# New York	40.71427	-74.00597
# Indonesia	-5	120
# Thailand	15.5	101
# Kuala Lumpur	3.1412	101.68653
# Jakarta	-6.21462	106.84513
# Johannesburg	-26.20227	28.04363
# London	51.50853	-0.12574
# Mozambique	-18.25	35
# Bulgaria	42.66667	25.25
# Philippines	13.40882	122.56155
# Golan Heights	32.90485	35.80725
# Kanaker	40.22302	44.53986
# Yaroun	33.08028	35.4225
# Sarit	35.47569	71.45229
# Aleppo	36.20124	37.16117
# Kyiv	50.45466	30.5238
# Israelpalestine	NA	NA
# Alaqsa	NA	NA
# Rawaa	NA	NA
# Alkarama	NA	NA
# Ras Issa	34.11528	35.72278
# Hodeidah Province	20.75	-75.91667
# Ebel Elsaqi	33.35667	35.62639
# Riyadh	24.68773	46.72185
# Bab Al	35.26943	69.68085
# Mandeb Strait	4	100
# Maghazi	31.42234	34.38501
# Near East	17.97421	-76.80663
# Davos	46.80429	9.83723
# Al Jazeera	14.6	33.35
# Almawasi	NA	NA
# Istanbul	41.01384	28.94966
# Crete	35.15585	24.89502
# Ankara	39.91987	32.85427
# Sweden	62	15
# Paris	48.85341	2.3488
# Eastern Mediterranean	39.42657	41.23464
# Bosnia	44	18
# Herzegovina	43	17.83333
# Serbia	44.81892	20.45998
# Montenegro	42.75	19.25
# Yugoslavia	44	19.75
# Salem	44.9429	-123.0351
# Copenhagen	55.67594	12.56553
# Ansarallah	NA	NA
# Washington Dc	47.50012	-120.50147
# Khan Yunis	31.34018	34.30627
# Mawasi	32.48133	68.85529
# Shadi	34.84836	60.42347
# Paltel	32.08712	35.18388
# Jawwal	NA	NA
# Walla	-2.85662	33.32102
# Berlin	52.52437	13.41053
# Gretna	41.14083	-96.23974
# Louisiana	31.00047	-92.0004
# New Orleans	29.95465	-90.07507
# Mirandacleland	NA	NA
# Caesarea	38.73222	35.48528
# Kefar Sava	32.175	34.90694
# Rehovot	31.89421	34.81199
# Beersheba	31.25181	34.7913
# Repjayapal	NA	NA
# Repcori	NA	NA
# Basedmikelee	NA	NA
# Republic Of Korea	24	121
# Libya	28	17
# Kosovo	42.58333	20.91667
# Brussels	50.85045	4.34878
# League Of Arab States	29.75634	-94.97187
# Gaza Deir Elbalah	35.65832	65.18016
# Almughraqa	NA	NA
# Almaghazi	NA	NA
# Maghazi Roads	43.84258	-68.88115
# Deir Albalah	31.41834	34.34933
# South Carolina	34.00043	-81.00009
# New York City	40.71427	-74.00597
# Arura	9.8694	76.30498
# Beruit	NA	NA
# Almazraa	NA	NA
# Mediterranean Sea	35.78	19.33
# Ajaq	35.64005	48.84628
# Silwad	31.97625	35.2613
# La France	45.20507	5.74629
# Ocean Jazz	-10	70
# Cape Town	-33.92584	18.42322
# South Africansfrom	38.02807	-97.94033
# Africa4Palestine	NA	NA
# Western Cape Province	40.64575	-79.91382
# Cyprus	35.00304	32.98791
# Akrotiri	36.35796	25.3976
# Limassol	34.68406	33.03794
# Pashias	NA	NA
# Anadolu	39	35
# Nevatim	31.22417	34.88098
# Republic Of Cyprus	24	121
# Dhekelia	35.01667	33.775
# Jenin	32.45943	35.30086
# Abwein	32.03144	35.19992
# Nablus	32.22111	35.25444
# Hebron	31.52935	35.0938
# Qalqilya	32.18583	35.06583
# Jericho	31.86667	35.45
# Pa	12.66667	-3.95
# Oslo	59.91273	10.74609
# Aqaba	29.52667	35.00778
# Houthi	NA	NA
# Majedalansari	NA	NA
# Kan	12.00012	8.51672
# Wadi Gaza	15	21.5
# Sri Lanka	7.75	80.75
# Almazraa Asharqiya	NA	NA
# Harvey	41.61003	-87.64671
# Tawfiq	33.01842	44.38071
# Aldabshah	NA	NA
# Khirbet Selm	33.22931	35.42407
# Bint Jbeil	33.11944	35.43333
# Ibil El Saqi	33.35667	35.62639
# Altawil	NA	NA
# Alkhader	NA	NA
# Bekaa Valley	33.83333	36
# Litani River	3.3	-54.1
# Iceland	65	-18
# Czech Republic	49.75	15
# Hungary	47	20
# Slovenia	46.08333	15
# Ireland	53	-8
# Carogennez	NA	NA
# Flanders	51	4.5
# Wallonia	50.5	4.75
# Tel Israel	32.25327	34.87034
# Aizawl	23.72894	92.71791
# Manipur	25	94
# Kangpokpi	25.15114	93.9695
# Mizoram	23	93
# Kingdom Of Judah	20.75028	-156.50028
# Bnei Menashe	32.08074	34.8338
# Kolasib	24.22388	92.67869
# Silicon Valley	37.37	-122.04
# Beit Shemesh	31.73072	34.99293
# Santa Clara	22.40694	-79.96472
# California	37.25022	-119.75126
# Moldova	47.25	28.58333
# Netivot	31.42305	34.58911
# Thameen Darby	NA	NA
# Nakba Layer	NA	NA
# Mercator	NA	NA
# Alaska	64.00028	-150.00028
# South America	-14.60485	-57.65625
# Asiapacific	NA	NA
# Crimea	45	34
# South China Sea	51.53782	0.71433
# Vietnam	16.16667	107.83333
# Kashmir	30.33315	63.19089
# Islamabad	33.72148	73.04329
# Darby Nakba	46.0227	-114.17814
# Panjgur	26.75	64
# Pakistan Balochistan Province	41.22825	33.15674
# Sistanbaluchestan Province	28.5	60.5
# Islamic Republic Of Iran	32	53
# Kerman	30.28321	57.07879
# Islamic Republic	32	53
# Nur Shams	51.1801	71.44598
# Tulkarem	32.31156	35.0269
# Naqoura	33.11806	35.13972
# America	26.0173	-104.41406
# Ein Alhilweh	32.62899	34.94483
# Basel	47.55839	7.57327
# Ofer	32.62257	34.98302
# Jordan Valley	42.97404	-117.0543
# Kadri	3.34322	30.99265
# Aljiftlik	NA	NA
# Farsiya	35.95584	42.96643
# Makhoul	33.40788	37.3558
# Tubas	32.32091	35.36989
# Areas A	-16.39889	-71.535
# Uganda	1.25	32.5
# Kuwait	29.5	47.75
# Chicago	41.85003	-87.65005
# Dena	28.44289	90.28327
# Oakland	37.80437	-122.2708
# Syria Aleppo	33.26954	35.19626
# Mariupol	47.09514	37.54131
# Zeitoun	34.06222	35.68528
# Alamal	31.39064	37.3146
# Alnasser	NA	NA
# Alkatiba	NA	NA
# Naksbilal	NA	NA
# Almawasi District	14.3656	44.7778
# Erbil	36.19117	44.00943
# Iran Sistanbaluchestan Province	32	53
# Rask	29.49114	57.18543
# Sistanbaluchestan	NA	NA
# Strait Of Hormuz	26.56667	56.25
# Persian Gulf	27	51
# Balochistan	28.47849	65.64355
# Middle East Eye	33.13906	35.85869
# Eilat	29.55805	34.94821
# Ashdod	31.79213	34.64966
# Dead Sea	44.86777	-73.62391
# Eastern Mediterranean Region	39.42657	41.23464
# Farhana	NA	NA
# Abudaqa	NA	NA
# Dahiyeb	NA	NA
# Aroura	38.92219	-111.93409
# Alarouri	NA	NA
# Rohtak	28.89447	76.58917
# Haryana	29.25	76.33333
# Uttar Pradesh	27.25	80.75
# Lucknow	26.83928	80.92313
# Up	43.62841	6.22477
# Bihar	25.75	85.75
# West Bengal	19.38333	-71.21667
# Benarasiyaa	NA	NA
# Haryana Panipat	29.25	76.33333
# Middle Eastern	33.13906	35.85869
# Haryana Jind	29.25	76.33333
# Hebrew	NA	NA
# Portugal	39.6945	-8.13057
# Maroun El Ras	33.10381	35.4444
# Rmeish	NA	NA
# Miraj	16.8671	74.70146
# Tal Alhawa	-36.72494	-73.11684
# Zarahsultana	NA	NA
# Gisha	-1.744	29.9586
# Bani Naim	15.88333	43.78333
# Raanana	32.1836	34.87386
# Sderot	31.525	34.59693
# Nir Am	31.51959	34.58006
# Mefalsim	31.50125	34.5637
# Hanita	33.08746	35.17364
# Mattat	33.04134	35.35858
# Margaliot	NA	NA
# Adamit	33.07971	35.21103
# Zarit	33.09955	35.2889
# Malkia	60.75482	24.06197
# Dubai	25.07725	55.30927
# Bab Almandeb	12.60416	43.33557
# Yemen Southern Coast	12.79891	45.03313
# Kampala	0.31628	32.58219
# Bahaa Eldin Abu Ras	33.53699	36.31307
# Dura	28.8	49.23333
# Bahaa	NA	NA
# Manchester City	42.99564	-71.45479
# Barcelona	41.38879	2.15899
# Syria Damascus	33.26954	35.19626
# Mazzeh	NA	NA
# Borj El Barajneh	33.84347	35.49874
# Palestine_Un	NA	NA
# Dahiya	8.0264	80.533
# Jamaa Islamiya	35.46804	-5.70106
# Southern Africa	-27.11781	22.28027
# Redsea	NA	NA
# El Amal City Hospital	32.893	0.54839
# Jordan River	31	36
# Alshifa	NA	NA
# Israel Haifa	41.68181	-70.27889
# Hamoud	15.64004	-11.51864
# Taalbaya	NA	NA
# Shatila	42.65879	45.15632
# Rashidiya	25.22499	55.38947
# Venezuela	8	-66
# Hormuz	27.5026	54.2839
# Arabian Gulf	26.35058	50.16805
# Gulf Of Oman	8.5	79
# Khreis	25.05944	48.06389
# Northern Gaza	54.77535	-105.64453
# Lisbon	38.71667	-9.13333
# Des Moines	41.60054	-93.60911
# Iowa	42.00027	-93.50049
# Tunisia	34	9
# Cedar Rapids	42.00833	-91.64407
# Iowa City	41.66113	-91.53017
# South Asia	21.28937	78.66211
# Florida	28.75054	-82.5001
# New York Ellis Island	40.71427	-74.00597
# Ohio	40.25034	-83.00018
# Zawayda	NA	NA
# Beit Hanoon	31.5353	34.53579
# Syria Golan Heights	35	38
# Kurdistan	37	44
# Panjgur Pakistan Balochistan Province	48.11313	16.86215
# Belarus	53	28
# Bosniaherzegovina	NA	NA
# Srebrenica	44.10748	19.29669
# Eurasia	87	80
# Heliopolis	36.50361	7.44278
# Alfawakhir	NA	NA
# Levant	34	36
# Gaza City Zeitoun	41.72621	-72.44008
# Old City Of Gaza	38.53998	-109.49567
# Mecca	21.42664	39.82563
# Gaza Daraj	31.50161	34.46672
# Almasjid Alomari Alkabir	35.13444	36.74545
# Byzantium	41.01384	28.94966
# Via Maris	47.87844	27.16671
# Anthedon	38.49842	23.44886
# Balakhiyah	NA	NA
# Tida	31.24415	30.83845
# Tell Elajjul	36.53984	40.61373
# Calves Hill	42.27426	-71.32284
# Daraj	33.24567	59.54541
# Ahmadiyyah Zawiya	NA	NA
# X	19.22364	-70.53051
# Spain	40	-4
# Madrid	40.4165	-3.70256
# Oman	21	57
# Vienna	48.20849	16.37208
# Manchester	42.99564	-71.45479
# Hyderabad	17.38405	78.45636
# Colombo Kollupitiya	-76.51667	-144.73333
# Bab Elmandeb Strait	12.60416	43.33557
# Southern Red Sea	21.28937	78.66211
# Africa Cape Of Good Hope	18.31281	-4.83398
# Scotland	56	-4
# Egypt Sinai Peninsula	31.19518	29.90976
# Philadelphi	NA	NA
# Charleston	32.77632	-79.93275
# Alfukhari	NA	NA
# Cameroon	6	12.5
# Alahli	NA	NA
# West Jerusalem	31.78199	35.21961
# Seychelles	-4.58333	55.66667
# Marib	15.6213	46.0111
# Motaz	NA	NA
# Azaizamotaz9	NA	NA
# Sabra	34.83042	-1.547
# Somalia	6	48
# Yemen Red Sea	12.79891	45.03313
# Hajjah	15.69425	43.60582
# Taiz Province	13.5	44
# Peru	-10	-75.25
# Colombia	4	-73.25
# South Sudan	7.5	30
# Swaziland	-26.5	31.5
# Lama Khater	9.55111	1.18611
# Kiryat Arba	33.20733	35.57212
# Malta	35.91667	14.43333
# Northgaza	NA	NA
# Earth	0	0
# Entebbe Uganda	0.04239	32.4435
# Sierra Leone	8.5	-11.5
# Drc	-17.98192	20.76806
# Adoniaayebare	NA	NA
# Republic Of Yemen	24	121
# West Beirut	51.48653	-0.40583
# Beirut Hamra	33.89332	35.50157
# Hamra	31.81088	-8.27151
# West Beirutis	19.38333	-71.21667
# Dabbouch	NA	NA
# East Beirut	37.02332	-77.36954
# Bani Suheila	31.34337	34.32337
# Kiryat Shmona	33.20733	35.57212
# Blue Line	40.88291	-123.98395
# Santiago	-33.45694	-70.64827
# Hezbollah	29.8628	56.8848
# Deir Qaddis	35.33588	40.14084
# Al Rayyan	25.29194	51.42444
# Bern	46.94809	7.44744
# Zurich	47.36667	8.55
# Gazas	-23.5	33
# Tomwhitegaza	NA	NA
# Entebbe	0.05621	32.47949
# Rwanda	-2	30
# East Timor	-8.83333	125.75
# Kabul	34.52813	69.17233
# Azzahra	19.11437	41.91694
# Hamad	31.40307	48.45684
# State Of Qatar	25.5	51.25
# Qffd	NA	NA
# Lebanon Nabatieh	37.83451	-85.7319
# Yiron	33.07757	35.4546
# Avivim	33.08892	35.47228
# Israel Goren	41.68181	-70.27889
